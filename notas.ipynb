# %% [markdown]
# - `check_sudoku(sudoku)`
#
#     1. `check_cuadrado(sudoku)`
#
#     2. `check_numeros_validos(sudoku)`
#
#     3. `check_filas(sudoku)`
#
#     4. `check_columnas(sudoku)`
#
#
# - elejir nombres de casos test
#
# 749-
